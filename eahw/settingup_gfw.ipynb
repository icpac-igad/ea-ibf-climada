# %%
1. Start the windows docker for desktop program to start the docker in debian bash
2. To start the image use 
     sudo docker run -dit -p 8889:8889 airpollutionstudyindia/climada_x64:version04
3. to get inside the image by 
    sudo docker exec -it 67e5f bash
4. to run the jupyte notebook inside the contaner and use it from a browser in windows.
   Run the jupyter from the docker by 
    conda activate climada_env
    jupyter notebook --ip 0.0.0.0 --port=8889 --no-browser --allow-root
5. The jupyter notebook can be viewed from windws browser, after the start of jupyter notebook	
   by copy pasting the link provided by jupyter in an browser, for example 
    http://127.0.0.1:8889/?token=9645a6dfdab666f9f6be6e2b9dfcf9a4be1da352b532f18d
6. To shutdown the port 
    lsof i:8889
	kill -9 id

# %%
Following the note on 

https://github.com/Vizzuality/gfw



    

sudo docker run -dit debian:stable
    
1. installing the yarn following https://www.vultr.com/docs/how-to-install-node-js--npm-on-debian-11/

curl -fsSL https://deb.nodesource.com/setup_19.x | sudo bash - &&\
sudo apt-get install -y nodejs
    
    
 adduser crow sudo

 add user
    9  adduser crow
   10  adduser crow sudo

  su crow
   12  history
   13  su crow
   14  exit


yarn --version
   51  sudo npm install -g yarn
   52  sudo rm /usr/bn/yarn
   53  sudo rm /usr/bin/yarn
   54  sudo npm install -g yarn
   55  sudo rm /usr/bin/yarnpkg
   56  sudo npm install -g yarn
   57  yarn --version
   58  yarn


  1  curl -fsSL https://deb.nodesource.com/setup_17.x | sudo -E bash -
    2  curl -fsSL https://deb.nodesource.com/setup_19.x | sudo bash - &&sudo apt-get install -y nodejs
    3  node -v
    4  npm -v
    5  corepack enable
    6  sudo corepack enable
    7  yarn
    8  git clone https://github.com/Vizzuality/gfw.git
    9  sudo apt install git
   10  git clone https://github.com/Vizzuality/gfw.git
   11  ls
   12  cd crow/
   13  git clone https://github.com/Vizzuality/gfw.git
   14  cd gfw/
   15  yarn
   16  ls -al
   17  nano .nvmrc
   18  sudo apt install crow
   19  sudo apt install nano
   20  nano .nvmrc
   21  node -v
   22  nano .nvmrc
   23  yarn
   24  nano .nvmrc
   25  history
   26  su root
   27  su
   28  exit
   29  node -v
   30  npm -v
   31  curl -o- https://raw.githubusercontent.com/nvm-sh/nvm/v0.37.2/install.sh | bash
   32  nvm -v
   33  export NVM_DIR="$HOME/.nvm"
   34  nvm -v
   35  source ~/.nvm/nvm.sh
   36  nvm -v
   37  nvm install 12.16.2
   38  nvm alias default 12.16.2
   39  nvm use 12.16.2
   40  node -v
   41  ls
   42  cd crow/
   43  ls
   44  cd gfw/
   45  ls
   46  nano .nvmrc
   47  yarn
   48  npm i -D @types/node
   49  yarn
   50  yarn --version
   51  sudo npm install -g yarn
   52  sudo rm /usr/bn/yarn
   53  sudo rm /usr/bin/yarn
   54  sudo npm install -g yarn
   55  sudo rm /usr/bin/yarnpkg
   56  sudo npm install -g yarn
   57  yarn --version
   58  yarn
   59  exit
   60  ls
   61  cd home
   62  ls
   63  history
crow@f98c168951d5:/home$
    
    
corepack enable

git clone https://github.com/Vizzuality/gfw.git

# %%
sudo docker run -dit -p 3000:3000 airpollutionstudyindia/gfw-node:version01

# %% [markdown]
# # On gsky

# %%
sudo docker run --rm -it -p 8080:8080 gjmouse/gsky:latest
        
        
Welcome to GSKY Docker

TerriaMap:               http://127.0.0.1:8080/terria
GSKY WMS/WCS end point:  http://127.0.0.1:8080/ows
MAS API end point:       http://127.0.0.1:8888
